# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMOGRAMAN**
#
# **“Struktur percabangan pada python”**
#
# **Disusun Oleh :**
#
# **Havis Lutfi**
#
# **2611531016**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan pemograman yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Praktikum Algoritma dan pemograman. Praktikum ini berfokus pada pembahasan struktur percabangan pada python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung struktur percabangan python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
#
# Havis Lutfi
# 2611531016

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pemograman merupakan fondasi utama dalam bidang informatika. Sebagai Mahasiswa baru ini perlu dikuasai supaya dapat memahami cara kerja instruksi komputer. Sebagai langkah awal python dipilih sebagai bahasa awal karena memiliki sintaks yang sederhana dan mudah dipahami.
#
# Pada perancangan program menggunakan python, dibutuhkan pemahaman terhadap struktur percabangan pada Python tersebut. Ada if, if-else, if-elif-else, mult-if, dan match-case. Struktur percabangan ini digunakan berdasarkan program apa yang kita buat dan memilih struktur percabangan apa saja yang akan kita gunanakan. Praktikum ini membentuk pemahaman yang mendasar-terhadap struktur percabangan pada python sehingga menanamkan pondasi yang kuat pada mahasiswa.
#
# ## 1.2 Tujuan
# 1. Mampu memahami dasar pemograman sebagai fondasi utama.
# 2. Memahami karakteristik masing-masing struktur percabangan pada python.
# 3. Mampu membuat program dengan struktur percabangan yang tepat menggunakan python.
# 4. Menerapkan fungsi dari struktur percabangan pada python.
# 5. Mengetahui bagaimana cara penerapan macam-macam struktur percabangan pada program.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat mengenal dan memahami dasar pemograman.
# 2. Mahasiswa mampu meranacang pemograman sederhana dengan menggunakan struktur percabangan yang tepat.
# 3. Mahasiswa dapat dapat menerapkan penggunaan dari berbagai struktur percabangan.
# 4. Mhasiswa dapat menerapkan penggunaan struktur percabangan yang tepat paa program..

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Pada praktikum ini mahasiswa melakukan pengenalan dan mengimplementasikan tentang struktur percabangan if, if-else, if-elif-else, multi-if, match-case.
#
# 1. Percabangan
#
#     Struktur percabangan dalam bahasa pemrograman Python adalah mekanisme untuk menentukan alur eksekusi program berdasarkan kondisi tertentu, menggunakan logika "jika-maka" (conditional statement).  Struktur ini memungkinkan program untuk berpikir dan mengambil keputusan serta mengeksekusi blok kode yang berbeda sesuai dengan nilai True atau False.
# 2. Pernyataan If.
#
#     Pernyataan if mengevaluasi suatu kondisi (ekspresi yang menghasilkan True atau False). Jika kondisinya benar, blok kode di dalam pernyataan if dijalankan. Jika kondisinya salah, blok kode dilewati.
# 3. Pernyataan If-else.
#
#     Pernyataan if-else digunakan untuk mengeksekusi satu blok kode ketika suatu kondisi Benar dan blok lain ketika kondisinya Salah. Ini membantu program membuat keputusan berdasarkan kondisi yang berbeda.
# 4. Pernyataan if-elif-else.
#
#       Pernyataan if-elif-else digunakan untuk memeriksa beberapa kondisi satu per satu. Ketika suatu kondisi menjadi True, blok kode yang sesuai akan dieksekusi. Jika tidak ada kondisi yang Benar, blok lain akan berjalan.
#
# 5. Pernyataan multi if.
#
#    Pernyataan multi-if memungkinkan beberapa blok dijalankan jika kondisinya masing-masing benar. Tidak seperti elif, yang berhenti memeriksa setelah kondisi benar pertama, pernyataan multi-if menjalankan semua blok kode yang kondisinya benar.
# 6. Match-case.
#
#       Pernyataan match-case mengevaluasi suatu nilai dan membandingkannya dengan satu atau lebih pola kasus. Ketika pola yang cocok ditemukan, blok kode yang sesuai dijalankan.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program if1_2611531016
# Program ini menggunakan 1 pernyataan if, dan menjalankan kode jika pernyataan if benar

# %%
#Buat file dengan nama if1_2611531016.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()

ipk_1016 = float(input("Input IPK Anda = "))

if ipk_1016 > 2.75:
    print("Anda lulus sangat memuasakan dengan IPK " + str(ipk_1016))

print("Program Selesai")

# %% [markdown]
# Hasil :

# %%
Input IPK Anda = 3
Anda lulus sangat memuasakan dengan IPK 3.0
Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. Masukkan input pengguna.
#     `ipk_1016 = float(input("Input IPK Anda = "))`
#     Kode tersebut meminta penguna untuk memasukkan nilai IPK dengan menggunakan fungsi `input()`. Masukan dari pengguna akan dikonversi menjadi tipe data float dengan menggunakan `float()`, nilai tersebut disimpan pada variabel `ipk_1016`.
#
# 2. Pernyataan if.
#     ```
#     if ipk_1016 > 2.75:
#     print("Anda lulus sangat memuasakan dengan IPK " + str(ipk_1016))
#     ```
#     Kode tersebut menggunakan pernyataan if dengan memeriksa apakah `ipk_1016` lebih besar dari 2.75. Jika benar program akan menjalankan kode didalamnya yaitu mencetak "Anda lulus sangat memuasakan dengan IPK" dan nilai ipk yang dimasukkan. Jika salah, pernyataan ini akan dilewatkan atau tidak dijalankan. Nilai ipk pada `ipk_1016` dikonversi dari yang awalnya float menjadi string menggunakan `str()`.
#
# 3. Cetak pesan.
#     `print("Program Selesai")`
#     Kode tersebut mencetak pesan "Program Selesai".

# %% [markdown]
# ### 2.2.2 Program if2_2611531016

# %% [markdown]
# Program ini menggunakan pernyataan if-else yang menjalankan kode dalam pernyataan if jika benar. Jika salah pernyataan else akan dijalankan

# %%
#Buat file dengan nama if2_2611531016.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()

ipk_1016 = float(input("Input IPK Anda = "))

if ipk_1016 > 2.75:
    print("Anda lulus sangat memuasakan dengan IPK " + str(ipk_1016))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")

# %% [markdown]
# Hasil:
#
# Jika Benar:

# %%
Input IPK Anda = 3
Anda lulus sangat memuasakan dengan IPK 3.0
Program Selesai

# %% [markdown]
# Jika salah:

# %%
Input IPK Anda = 2
Anda Tidak Lulus
Program Selesai

# %% [markdown]
# **Penjelasan :**
# 1. `ipk_1016 = float(input("Input IPK Anda = "))`
#     Kode tersebut meminta penguna untuk memasukkan nilai IPK dengan menggunakan fungsi `input()`. Masukan dari pengguna akan dikonversi menjadi tipe data float dengan menggunakan `float()`, nilai tersebut disimpan pada variabel `ipk_1016`.
#
# 2. ```
#     if ipk_1016 > 2.75:
#     print("Anda lulus sangat memuasakan dengan IPK " + str(ipk_1016))
#     ```
#     Kode tersebut menggunakan pernyataan if dengan memeriksa apakah `ipk_1016` lebih besar dari 2.75. Jika benar program akan menjalankan kode didalamnya yaitu mencetak "Anda lulus sangat memuasakan dengan IPK" dan nilai ipk yang dimasukkan. Nilai ipk pada `ipk_1016` dikonversi dari yang awalnya float menjadi string menggunakan `str()`.
#
# 3. ```
#     else:
#     print("Anda Tidak Lulus")
#     ```
#     pernyataan ini akan dijalankan jika pernyataan if salah. mencetak pesan "Anda Tidak Lulus"
#
# 4. `print("Program Selesai")`
#     Kode tersebut mencetak pesan "Program Selesai".

# %% [markdown]
# ### 2.2.3 Program multi_if1_2611531016

# %% [markdown]
# Program ini menggunakan multi if yang dimana akan menjalankan kode yang pernyataan if nya bernilai benar sesuai inputan pengguna.

# %%
#Buat file dengan nama if3_2611531016.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()

umur_1016 = int(input("Input umur anda: "))
sim_1016 = input("Apakah Anda Sudah Punya Sim C (y/t) : ")[0]

if umur_1016 >= 17 and sim_1016 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")

if umur_1016 >= 17 and sim_1016 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

if umur_1016 <= 17 and sim_1016 == 'y':
    print("Anda Belum Cukup Umur punya SIM")

if umur_1016 != 17 and sim_1016 != 'y':
    print("Anda Belum Cukup Umur bawa motor")

# %% [markdown]
# Hasil:

# %%
Input umur anda: 18
Apakah Anda Sudah Punya Sim C (y/t) : y
Anda Sudah dewasa dan boleh bawa motor

# %% [markdown]
# Penjelasan :
#
# 1. `umur_1016 = int(input("Input umur anda: "))`
#     program tersebut meminta pengguna untuk memasukkan umur yang akan dikonversi menjadi integer.
#
# 2.  `sim_1016 = input("Apakah Anda Sudah Punya Sim C (y/t) : ")[0]`
#     Meminta pengguna memasukkan status kepunyaan sim dengan mengetik y atau t. `[0]` digunakan untuk mengambil karakter pertama atau index 0 dari masukan pengguna.
#
# 3. ```
#     if umur_1016 >= 17 and sim_1016 == 'y':
#     print("Anda Sudah dewasa dan boleh bawa motor")
#     ```
#     Mengecek apakah `umur_1016` lebih atau sama dengan 17 dan `sim_1016` bernilai y. Jika kedua benar, akan mencetak "Anda Sudah dewasa dan boleh bawa motor".
#
# 4. ```
#     if umur_1016 >= 17 and sim_1016 != 'y':
#     print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
#     ```
#     Mengecek apakah `umur_1016` lebih atau sama dengan 17 dan `sim_1016` tidak bernilai y. Jika kedua benar, akan mencetak "Anda Sudah dewasa tetapi tidak boleh bawa motor".
#
# 5. ```
#     if umur_1016 <= 17 and sim_1016 == 'y':
#     print("Anda Belum Cukup Umur punya SIM")
#     ```
#     Mengecek apakah `umur_1016` kurang atau sama dengan 17 dan `sim_1016` bernilai y. Jika kedua benar, akan mencetak "Anda Belum Cukup Umur punya SIM".
#
# 6. ```
#     if umur_1016 != 17 and sim_1016 != 'y':
#     print("Anda Belum Cukup Umur bawa motor")
#     ```
#     Mengecek apakah `umur_1016` tidak sama dengan 17 dan `sim_1016` tidak bernilai y. Jika kedua benar, akan mencetak "Anda Belum Cukup Umur bawa motor".

# %% [markdown]
# ### 2.2.4 Program multi_if2_2611531016

# %% [markdown]
# Program ini menggunakan multi-if yang akan mengecek total belanja, status member, dan kode promo berdasarkan inputan pengguna.

# %%
#Buat file dengan nama multi_if2_2611531016.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_1016 = float(input("Masukkan total belanja (Rp)"))

# Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_1016 = input("Apakah Anda member? (y/t): ").strip().lower()
is_member_1016 = input_member_1016 in ["y", "ya"]

# Input status kode promo (mengecek user mengetik 'y' atau 'ya)
input_promo_1016 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_1016 = input_promo_1016 in ["y", "ya"]

total_diskon_persen_1016 = 0

# Multi-IF terpisah: Setiap kondisi diperika secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus
 
if total_belanja_1016 > 1000000:
    total_diskon_persen_1016 += 10  # Diskon belanja besar
  
if is_member_1016:
    total_diskon_persen_1016 += 5   # Diskon member

if kode_promo_valid_1016:
    total_diskon_persen_1016 += 15  # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_1016 = total_belanja_1016 * (total_diskon_persen_1016 / 100)
total_bayar_1016 = total_belanja_1016 - nominal_diskon_1016
 
# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon  : {total_diskon_persen_1016}% (Rp {nominal_diskon_1016:,.0f})")
print(f"Total Bayar   : Rp {total_bayar_1016:,.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_1016}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid

# %% [markdown]
# Hasil :

# %%
Masukkan total belanja (Rp)200000
Apakah Anda member? (y/t): y
Apakah kode promo valid? (y/t): y

--- Rincian Pembayaran ---
Total Diskon  : 20% (Rp 40,000)
Total Bayar   : Rp 160,000
Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# Penjelasan :
#
# 1. `total_belanja_1016 = float(input("Masukkan total belanja (Rp)"))`
#     Meminta pengguna memasukkan total belanja yang akan dikonversi menjadi tipe data float menggunakan `float()`.
#
# 2. ```
#     input_member_1016 = input("Apakah Anda member? (y/t): ").strip().lower()
#     is_member_1016 = input_member_1016 in ["y", "ya"]
#     ```
#     Meminta pengguna untuk memasukkan status member dengan menjawab y atau t. Menghapus semua spasi pada inputan pengguna menggunakan `.strip()` dan mengubah semua inputan pengguna menjadi huruf kecil menggunakan `.lower()` dan disimpan pada `input_member_1016`. Mengecek apakah nilai pada `input_member_1016` ada pada list.
#
# 3. ```
#     input_promo_1016 = input("Apakah kode promo valid? (y/t): ").strip().lower()
#     kode_promo_valid_1016 = input_promo_1016 in ["y", "ya"]
#     ```
#     Meminta pengguna untuk memasukkan apakah kode promo valid dengan menjawab y atau t. Menghapus semua spasi pada inputan pengguna menggunakan `.strip()` dan mengubah semua inputan pengguna menjadi huruf kecil menggunakan `.lower()` dan disimpan pada `input_promo_1016`. Mengecek apakah nilai pada `input_promo_1016` ada pada list.
#
# 4. `total_diskon_persen_1016 = 0`
#     Menginisialisasi nilai dari variabel `total_diskon_persen_1016`
#
# 5. ```
#     if total_belanja_1016 > 1000000:
#         total_diskon_persen_1016 += 10
#     ```
#     Jika total belanja lebih besar dari 1000000, nilai pada `total_diskon_persen_1016` akan bertambah 10.
#
# 6. ```
#     if is_member_1016:
#         total_diskon_persen_1016 += 5
#     ```
#     Jika `is_member_1016` benar, nilai pada `total_diskon_persen_1016` akan bertambah 5.
#
# 7. ```
#     if kode_promo_valid_1016:
#         total_diskon_persen_1016 += 15
#     ```
#     Jika nilai pada ` kode_promo_valid_1016` benar, nilai pada `total_diskon_persen_1016` akan bertambah 15.
#
# 8. ```
#     nominal_diskon_1016 = total_belanja_1016 * (total_diskon_persen_1016 / 100)
#     total_bayar_1016 = total_belanja_1016 - nominal_diskon_1016
#     ```
#     Menyimpan hasil perkalian dari `total_belanja_1016 * (total_diskon_persen_1016 / 100)` pada `nominal_diskon_1016`. Lalu menyimpan hasil pengurangan dari `total_belanja_1016 - nominal_diskon_1016` pada `total_bayar_1016`.
#
# 9. ```
#     print("\n--- Rincian Pembayaran ---")
#     print(f"Total Diskon  : {total_diskon_persen_1016}% (Rp {nominal_diskon_1016:,.0f})")
#     print(f"Total Bayar   : Rp {total_bayar_1016:,.0f}")
#     print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_1016}%")
#     ```
#     Mencetak rincian pembayaran yang berisi total diskon, nominal diskon dan total bayar. `f"...` digunakan suapay kita dapat menyelipkan variabel secara langsung ke dalam string dengan menggunakan `{}`.

# %% [markdown]
# ### 2.2.5 Program if_elif_else1_2611531016

# %% [markdown]
# Program ini menggunakan pernyatan if-elif-else untuk menjalankan program tentang sudah cukup umur dan boleh membawa motor

# %%
#Buat file dengan nama if_elif_else1_2611531016.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()

umur_1016 = int(input("Input umur anda: "))
sim_1016 = input("Apakah Anda Sudah Punya Sim C (y/t) : ")[0]

if umur_1016 >= 17 and sim_1016 == 'y':
    print("Anda Sudah dewasa dan boleh bawa motor")

elif umur_1016 >= 17 and sim_1016 != 'y':
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

elif umur_1016 <= 17 and sim_1016 == 'y':
    print("Anda Belum Cukup Umur punya SIM")

else:
    print("Anda Belum Cukup Umur dan tidak boleh bawa motor")
print("Program Selesai")

# %% [markdown]
# Hasil:

# %%
Input umur anda: 18
Apakah Anda Sudah Punya Sim C (y/t) : t
Anda Sudah dewasa tetapi tidak boleh bawa motor
Program Selesai

# %% [markdown]
# Penjelasan :
#
# 1. `umur_1016 = int(input("Input umur anda: "))`
#     program tersebut meminta pengguna untuk memasukkan umur yang akan dikonversi menjadi integer.
#
# 2.  `sim_1016 = input("Apakah Anda Sudah Punya Sim C (y/t) : ")[0]`
#     Meminta pengguna memasukkan status kepunyaan sim dengan mengetik y atau t. `[0]` digunakan untuk mengambil karakter pertama atau index 0 dari masukan pengguna.
#
# 3. ```
#     if umur_1016 >= 17 and sim_1016 == 'y':
#     print("Anda Sudah dewasa dan boleh bawa motor")
#     ```
#     Mengecek apakah `umur_1016` lebih atau sama dengan 17 dan `sim_1016` bernilai y. Jika kedua benar, akan mencetak "Anda Sudah dewasa dan boleh bawa motor". Jika salah akan lanjut ke elif.
#
# 4. ```
#     elif umur_1016 >= 17 and sim_1016 != 'y':
#     print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
#     ```
#     Mengecek apakah `umur_1016` lebih atau sama dengan 17 dan `sim_1016` tidak bernilai y. Jika kedua benar, akan mencetak "Anda Sudah dewasa tetapi tidak boleh bawa motor". Jika salah akan lanjut ke elif.
#
# 5. ```
#     elif umur_1016 <= 17 and sim_1016 == 'y':
#     print("Anda Belum Cukup Umur punya SIM")
#     ```
#     Mengecek apakah `umur_1016` kurang atau sama dengan 17 dan `sim_1016` bernilai y. Jika kedua benar, akan mencetak "Anda Belum Cukup Umur punya SIM". Jika salah akan lanjut ke else
#
# 6. ```
#     else:
#         print("Anda Belum Cukup Umur dan tidak boleh bawa motor")
#     ```
#     Karena semua pernyataan if dan elif sebelumnya salah, program akan langsung mencetak "Anda Belum Cukup Umur dan tidak boleh bawa motor" tanpa mengecek kondisi apapun.
#
# 7. `print("Program Selesai")`
#     Mencetak "Program Selesai"

# %% [markdown]
# ### 2.2.6 Program match_case1_2611531016

# %% [markdown]
# Program menggunakan pernyataan `match` dan `case` untuk melakukan percabangan dengan mencocokkan inputan pengguna dengan case.

# %%
#Buat file dengan nama match_case1_2611531016.py
# Buat program untuk match case
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()
# Program konversi angka jadi nama bulan

bulan_1016 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_1016:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")

# %% [markdown]
# Hasil:

# %%
Masukkan angka bulan (1 - 12): 2
Februari

# %% [markdown]
# Hasil lain:

# %%
Masukkan angka bulan (1 - 12): 17
Angka tidak valid

# %% [markdown]
# Penjelasan :
#
# 1. `bulan_1016 = int(input("Masukkan angka bulan (1 - 12): "))`
#     Meminta pengguna untuk memasukkan angka bulan dari 1 sampai 12. Nilai tersebut akan disimpan pada variabel `bulan_1016` dan masukan pengguna tersebut akan dikonversi menjadi integer menggunakan `int()`
#
# 2. `match bulan_1016:`
#     Menggunakan struktur `match-case` untuk mencocokkan nilai dari bulan_1016
#
# 3. ```
#     case 1:
#         print("Januari")
#     case 2:
#         print("Februari")
#     case 3:
#         print("Maret")
#     case 4:
#         print("April")
#     case 5:
#         print("Mei")
#     case 6:
#         print("Juni")
#     case 7:
#         print("Juli")
#     case 8:
#         print("Agustus")
#     case 9:
#         print("September")
#     case 10:
#         print("Oktober")
#     case 11:
#         print("November")
#     case 12:
#         print("Desember")
#     ```
#     Mencocokkan nilai pada `bulan_1016`. jika nilai `bulan_1016` bernilai 1 akan mencetak "Januari", jika bernilai 2 akan mencetak "February", jika bernilai 3 akan mencetak "Maret", dan begitu seterusnya hingga bernilai 12 dan mencetak "Desember".
#
# 4. ```
#     case _:
#         print("Angka tidak valid")
#     ```
#     Jika nilai angka pada `bulan_1016` tidak ada yang cocok dengan case 1 sampai 12, program akan mencetak "Angka tidak valid".

# %% [markdown]
# ### 2.2.7 nilai_2611531016

# %% [markdown]
# Program menggunakan pernyataan if-elif-else untuk mencetak skor berdasarkan nilai.

# %%
# Buat file dengan nama nilai_2611531016.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit nim terakhir
# Program ini menggunakan fungsi input()
# program konversi nilai angka menjadi huruf

nilai_1016 = int(input("Inputkan nilai angka= "))

if nilai_1016 >= 81:
    print("A")
elif nilai_1016 >= 70:
    print("B")
elif nilai_1016 >= 60:
    print("C")
elif nilai_1016 >= 50:
    print("D")
else:
    print("E")

# %% [markdown]
# Hasil:

# %%
Inputkan nilai angka= 75
B

# %% [markdown]
# Penjelasan :
#
# 1. `nilai_1016 = int(input("Inputkan nilai angka= "))`
#     Meminta pengguna memasukkan nilai angka yang akan disimpan pada `nilai_1016`. Masukan pengguna akan dikonversi menjadi integer menggunakan `int()`.
#
# 2. ```
#     if nilai_1016 >= 81:
#         print("A")
#     ```
#     Mengecek apakah `nilai_1016` lebih besar atau sama dengan 81. Jika benar maka akan mencetak "A". Jika salah maka akan lanjut ke elif selanjutnya.
#
# 3. ```
#     if nilai_1016 >= 70:
#         print("B")
#     ```
#     Mengecek apakah `nilai_1016` lebih besar atau sama dengan 70. Jika benar maka akan mencetak "B". Jika salah maka akan lanjut ke elif selanjutnya.
#
# 4. ```
#     elif nilai_1016 >= 60:
#         print("C")
#     ```
#     Mengecek apakah `nilai_1016` lebih besar atau sama dengan 60. Jika benar maka akan mencetak "C". Jika salah maka akan lanjut ke elif selanjutnya.
#
# 5. ```
#     elif nilai_1016 >= 50:
#         print("D")
#     ```
#     Mengecek apakah `nilai_1016` lebih besar atau sama dengan 50. Jika benar maka akan mencetak "D". Jika salah maka akan lanjut ke else.
#
# 2. ```
#     else:
#         print("E")
#     ```
#     Jika tidak ada pernyataan if dan elif yang bernilai benar maka prgram akan langsung menjalankan else dan mencetak "E".

# %% [markdown]
# ### 2.2.8 Program tugas4_2611531016

# %% [markdown]
# Program yang berisikan penerapan sederhana dari if, if-elif-else, if-else, multi-if, dan match-case berupa sistem loket alpro adventure park.

# %%
#Tugas 4 Havis Lutfi
#Nim 2611531016
# Inputan pengguna
print("===SISTEM LOKET ALPRO ADVENTURE PARK===")
nama_1016 = input("Masukkan Nama Pengunjung : ")
umur_1016 = int(input("Masukkan umur anda       : "))
sim_1016 = input("apakah Anda Sudah Punya SIM C (y/t) : ").strip().lower()[0]

#Daftar paket
print("\nPilihan Paket Wahana (1-5):")
print("1. Safari Rimba           (Rp 50,000)")
print("2. Arung Jeram            (Rp 75,000)")
print("3. Motor ATV Ekstrim      (Rp 120,000)")
print("4. Roller Coaster Kilat   (Rp 100,000)")
print("5. All-Access VIP         (Rp 220,000)\n")

#inputan pengguna
nomor_paket_1016 = int(input("Masukkan nomor paket (1-5)     : "))
jumlah_tiket_1016 = int(input("Masukkan jumlah tiket          : "))
status_member_1016 = input("Apakah Anda member? (y/t)      : ").strip().lower()[0]
promo_valid_1016 = input("Apakah kode promo valid? (y/t) : ").strip().lower()[0]

#if tunggal
if jumlah_tiket_1016 <= 0:
    print("Jumlah tiket gak valid nichh!")
    exit()

#Match case
#ribet kali kalau ga boleh pake nested if mahhh-_-
match nomor_paket_1016:
    case 1:
        print("\n---KELAYAKAN WAHANA---")
        if umur_1016 >= 10:
            print("Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba")
        else:
            print("Status Akses : Anda belum cukup umur, harus didampingi oleh orang dewasa")
        harga_1016 = 50000
        pilihan_paket_1016 = "Safari Rimba"

    case 2:
        print("\n---KELAYAKAN WAHANA---")
        if umur_1016 >= 10:
            print("Status Akses : Anda sudah cukup umur untuk masuk wahana Arung Jeram")
        else:
            print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Arung Jeram!")
        pilihan_paket_1016 = "Arung Jeram"
        harga_1016 = 75000


    case 3:
        #if elif else
        print("\n---KELAYAKAN PENGENDARA WAHANA---")
        if umur_1016 >= 17 and sim_1016 == 'y':
            print("Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri")
        elif umur_1016 >= 17 and sim_1016 != 'y':
            print("Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
        elif umur_1016 < 17 and sim_1016 == 'y':
            print("Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.")
        else:
            print("Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV")
        pilihan_paket_1016 = "Motor ATV Ekstrim"
        harga_1016 = 120000

    case 4:
        print("\n---KELAYAKAN WAHANA---")
        if umur_1016 >= 10:
            print("Status Akses : Anda sudah cukup umur untuk masuk wahana Roller Coaster Kilat")
        else:
            print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Roller Coaster Kilat!")
        pilihan_paket_1016 = "Roller Coaster Kilat"
        harga_1016 = 100000

    case 5:
        #Wahana ATV
        #If elif else
        print("\n---KELAYAKAN PENGENDARA WAHANA---")
        if umur_1016 >= 17 and sim_1016 == 'y':
            print("Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri")
        elif umur_1016 >= 17 and sim_1016 != 'y':
            print("Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
        elif umur_1016 < 17 and sim_1016 == 'y':
            print("Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.")
        else:
            print("Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV")
        #Wahana lain
        print("\n---KELAYAKAN WAHANA---")
        if umur_1016 >= 10:
            print("Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba, Arung Jeram, Roaller Coaster Kilat")
        else:
            print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Safari Rimba, Arung Jeram, Roller Coaster Kilat!")
        pilihan_paket_1016 = "All-Access VIP"
        harga_1016 = 220000

    case _:
        print("Paket wahana tidak valid!")
        exit()



#inisialisasi
# Multi if
subtotal_1016 = jumlah_tiket_1016 * harga_1016
total_diskon_persen_1016 = 0
if subtotal_1016 >= 200000:
    total_diskon_persen_1016 += 10
if status_member_1016 in ['y', 'ya']:
    total_diskon_persen_1016 += 5
if promo_valid_1016 in ['y', 'ya']:
    total_diskon_persen_1016 += 15
if jumlah_tiket_1016 >= 5:
    total_diskon_persen_1016 += 5

total_diskon_1016 = subtotal_1016 * (total_diskon_persen_1016/100)
total_bayar_1016 = subtotal_1016 - total_diskon_1016

#Rincian
print("\n---Rincian Pembayaran---")
print(f"Nama Pengunjung   : {nama_1016}")
print(f"Pilihan Paket     : {pilihan_paket_1016}")
print(f"Subtotal Belanja  : Rp {subtotal_1016:,.0f}")
print(f"Total Diskon      : {total_diskon_persen_1016}% (Rp {total_diskon_1016:,.0f}) ")
print(f"Total Bayar       : Rp {total_bayar_1016:,.0f}")
if total_bayar_1016 > 300000:
    print("Selamat! Anda berhak mendapatkan Souvenir Gratis.")
    print("Terima kasih telah berkunjung.")
else:
    print("Terima kasih telah berkunjung.")
print("Program Selesai")

# %% [markdown]
# Hasil:

# %%
===SISTEM LOKET ALPRO ADVENTURE PARK===
Masukkan Nama Pengunjung : Havis Lutfi
Masukkan umur anda       : 18
apakah Anda Sudah Punya SIM C (y/t) : y

Pilihan Paket Wahana (1-5):
1. Safari Rimba           (Rp 50,000)
2. Arung Jeram            (Rp 75,000)
3. Motor ATV Ekstrim      (Rp 120,000)
4. Roller Coaster Kilat   (Rp 100,000)
5. All-Access VIP         (Rp 220,000)

Masukkan nomor paket (1-5)     : 5
Masukkan jumlah tiket          : 3
Apakah Anda member? (y/t)      : Ya
Apakah kode promo valid? (y/t) : ya

---KELAYAKAN PENGENDARA WAHANA---
Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri

---KELAYAKAN WAHANA---
Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba, Arung Jeram, Roaller Coaster Kilat

---Rincian Pembayaran---
Nama Pengunjung   : Havis Lutfi
Pilihan Paket     : All-Access VIP
Subtotal Belanja  : Rp 660,000
Total Diskon      : 30% (Rp 198,000) 
Total Bayar       : Rp 462,000
Selamat! Anda berhak mendapatkan Souvenir Gratis.
Terima kasih telah berkunjung.
Program Selesai

# %% [markdown]
# Penjelasan :
#
# 1. ```
#     print("===SISTEM LOKET ALPRO ADVENTURE PARK===")
#     nama_1016 = input("Masukkan Nama Pengunjung : ")
#     umur_1016 = int(input("Masukkan umur anda       : "))
#     sim_1016 = input("apakah Anda Sudah Punya SIM C (y/t) : ").strip().lower()[0]
#     ```
#     Meminta pengguna untuk memasukkan input berupa nama, umur, dan status punya sim. Umur diubah menjadi integer menggunakan int(). Pengguna diminta memasukkan y/t pada status sim. `.strip()` digunakan untuk menghapus spasi pada inputan pengguna. `.lower()` digunakan untuk mengubah inputan pengguna menjadi huruf kecil. `[0]` digunakan untuk mengambil karakter pertama atau index 0 pada inputan pengguna.
#
# 2. ```
#     print("\nPilihan Paket Wahana (1-5):")
#     print("1. Safari Rimba           (Rp 50,000)")
#     print("2. Arung Jeram            (Rp 75,000)")
#     print("3. Motor ATV Ekstrim      (Rp 120,000)")
#     print("4. Roller Coaster Kilat   (Rp 100,000)")
#     print("5. All-Access VIP         (Rp 220,000)\n")
#     ```
#     Mencetak pilihan paket wahana yang tersedia berserta harganya.
#
# 3. ```
#     nomor_paket_1016 = int(input("Masukkan nomor paket (1-5)     : "))
#     jumlah_tiket_1016 = int(input("Masukkan jumlah tiket          : "))
#     status_member_1016 = input("Apakah Anda member? (y/t)      : ").strip().lower()[0]
#     promo_valid_1016 = input("Apakah kode promo valid? (y/t) : ").strip().lower()[0]
#     ```
#     Meminta pengguna untuk memasukkan nomor paket yang dipilih, jumlah tiket, status member, dan apakah promo valid. nomor paket dan jumlah tiket diubah menjadi integer menggunakan `int()`. Pengguna diminta memasukkan y/t pada status member dan promo. `.strip()` digunakan untuk menghapus spasi pada inputan pengguna. `.lower()` digunakan untuk mengubah inputan pengguna menjadi huruf kecil. `[0]` digunakan untuk mengambil karakter pertama atau index 0 pada inputan pengguna.
#
# 4. ```
#     if jumlah_tiket_1016 <= 0:
#         print("Jumlah tiket gak valid nichh!")
#         exit()
#     ```
#     Jika jumlah tiket kurang atau sama dengan 0 maka akan mencetak "Jumlah tiket gak valid nichh!" dan akan menghentikan eksekusi program dengan menggunakan `exit()`.
#
# 5. `match nomor_paket_1016:`
#     Mencocokkan nilai pada `nomor_paket_1016` cocok dengan case yang ada.
#
# 6. ```
#     case 1:
#         print("\n---KELAYAKAN WAHANA---")
#         if umur_1016 >= 10:
#             print("Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba")
#         else:
#             print("Status Akses : Anda belum cukup umur, harus didampingi oleh orang dewasa")
#         harga_1016 = 50000
#         pilihan_paket_1016 = "Safari Rimba"
#     ```
#     Jika nilai pada `nomor_paket_1016` bernilai 1, maka akan mencetak ---KELAYAKAN WAHANA---. Melakukan percabangan, jika `umur_1016 >= 10` bernilai benar akan mencetak "Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba". Jika salah akan mencetak "Status Akses : Anda belum cukup umur, harus didampingi oleh orang dewasa". Memasukkan nilai 50000 pada `harga_1016`, dan memasukkan nilai "Safari Rimba" pada `pilihan_paket_1016`.
#
# 7. ```
#     case 2:
#         print("\n---KELAYAKAN WAHANA---")
#         if umur_1016 >= 10:
#             print("Status Akses : Anda sudah cukup umur untuk masuk wahana Arung Jeram")
#         else:
#             print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Arung Jeram!")
#         pilihan_paket_1016 = "Arung Jeram"
#         harga_1016 = 75000
#     ```
#     Jika nilai pada `nomor_paket_1016` bernilai 2, maka akan mencetak ---KELAYAKAN WAHANA---. Melakukan percabangan, jika `umur_1016 >= 10` bernilai benar akan mencetak "Status Akses : Anda sudah cukup umur untuk masuk wahana Arung Jeram". Jika salah akan mencetak "Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Arung Jeram!". Memasukkan nilai 75000 pada `harga_1016`, dan memasukkan nilai "Arung Jeram" pada `pilihan_paket_1016`.
#
# 8. ```
#     case 3:
#         #if elif else
#         print("\n---KELAYAKAN PENGENDARA WAHANA---")
#         if umur_1016 >= 17 and sim_1016 == 'y':
#             print("Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri")
#         elif umur_1016 >= 17 and sim_1016 != 'y':
#             print("Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
#         elif umur_1016 < 17 and sim_1016 == 'y':
#             print("Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.")
#         else:
#             print("Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV")
#         pilihan_paket_1016 = "Motor ATV Ekstrim"
#         harga_1016 = 120000
#     ```
#     Jika nilai pada `nomor_paket_1016` bernilai 3, maka akan mencetak ---KELAYAKAN PENGENDARA WAHANA---. Melakukan percabangan, jika `umur_1016 >= 17 and sim_1016 == 'y'` bernilai benar akan mencetak "Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri". Jika salah akan lanjut ke `elif` berikutnya. Jika `elif umur_1016 >= 17 and sim_1016 != 'y':` bernilai benar maka akan mencetak "Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)". Jika salah maka akan lanjut ke `elif` berikutnya. Jika `elif umur_1016 < 17 and sim_1016 == 'y':` bernilai benar maka akan mencetak "Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.". Jika salah akan melanjutkan ke `else` danlangsung mencetak "Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV".  Memasukkan nilai 120000 pada `harga_1016`, dan memasukkan nilai "Motor ATV Ekstrim" pada `pilihan_paket_1016`.
#
# 9. ```
#     case 4:
#         print("\n---KELAYAKAN WAHANA---")
#         if umur_1016 >= 10:
#             print("Status Akses : Anda sudah cukup umur untuk masuk wahana Roller Coaster Kilat")
#         else:
#             print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Roller Coaster Kilat!")
#         pilihan_paket_1016 = "Roller Coaster Kilat"
#         harga_1016 = 100000
#     ```
#     Jika nilai pada `nomor_paket_1016` bernilai 4, maka akan mencetak ---KELAYAKAN WAHANA---. Melakukan percabangan, jika `umur_1016 >= 10` bernilai benar akan mencetak "Status Akses : Anda sudah cukup umur untuk masuk wahana Roaller Coaster Kilat". Jika salah akan mencetak "Status Akses : Anda belum cukup umur, tidak bisa masuk wahana Roller Coaster Kilat!". Memasukkan nilai 100000 pada `harga_1016`, dan memasukkan nilai "Roller Coaster Kilat" pada `pilihan_paket_1016`.
#
# 10. ```
#     case 5:
#         #Wahana ATV
#         #If elif else
#         print("\n---KELAYAKAN PENGENDARA WAHANA---")
#         if umur_1016 >= 17 and sim_1016 == 'y':
#             print("Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri")
#         elif umur_1016 >= 17 and sim_1016 != 'y':
#             print("Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur).")
#         elif umur_1016 < 17 and sim_1016 == 'y':
#             print("Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.")
#         else:
#             print("Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV")
#         #Wahana lain
#         print("\n---KELAYAKAN WAHANA---")
#         if umur_1016 >= 10:
#             print("Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba, Arung Jeram, Roaller Coaster Kilat")
#         else:
#             print("Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Safari Rimba, Arung Jeram, Roller Coaster Kilat!")
#         pilihan_paket_1016 = "All-Access VIP"
#         harga_1016 = 220000
#     ```
#     Jika nilai pada `nomor_paket_1016` bernilai 5, maka akan mencetak ---KELAYAKAN PENGENDARA WAHANA---. Melakukan percabangan, jika `umur_1016 >= 17 and sim_1016 == 'y'` bernilai benar akan mencetak "Status Akses : Anda Sudah dewasa dan boleh mengendarai ATV sendiri". Jika salah akan lanjut ke `elif` berikutnya. Jika `elif umur_1016 >= 17 and sim_1016 != 'y':` bernilai benar maka akan mencetak "Status Akses : Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)". Jika salah maka akan lanjut ke `elif` berikutnya. Jika `elif umur_1016 < 17 and sim_1016 == 'y':` bernilai benar maka akan mencetak "Status Akses : Identitas tidak valid: Belum cukup umur memiliki SIM.". Jika salah akan melanjutkan ke `else` danlangsung mencetak "Status Akses : Anda belum cukup umur dan tidak boleh bawa motor ATV".
#
#     Lanjut mencetak ---KELAYAKAN WAHANA---. Melakukan percabangan, jika `umur_1016 >= 10` bernilai benar akan mencetak "Status Akses : Anda sudah cukup umur untuk masuk wahana Safari Rimba, Arung Jeram, Roaller Coaster Kilat". Jika salah akan mencetak "Status Akses : Anda belum cukup umur,tidak bisa masuk wahana Safari Rimba, Arung Jeram, Roller Coaster Kilat!". Memasukkan nilai 220000 pada `harga_1016`, dan memasukkan nilai "All-Access VIP" pada `pilihan_paket_1016`.
#
# 11. ```
#     case _:
#         print("Paket wahana tidak valid!")
#         exit()
#     ```
#     Jika nilai pada `nomor_paket_1016` ttidak cocok dengan case manapun maka akan mencetak "Paket wahana tidak valid!" dan mengentikan eksekusi kode program dengan menggunakan `exit()`.
#
# 12. ```
#     subtotal_1016 = jumlah_tiket_1016 * harga_1016
#     total_diskon_persen_1016 = 0
#     ```
#     Menginisialisasi `subtotal_1016` dan memberinya nilai dengan hasil kali `jumlah_tiket_1016` dengan `harga_1016`. Menginisialisasi `total_diskon_persen_1016` dan memberi nilai 0.
#
# 13. ```
#     if subtotal_1016 >= 200000:
#         total_diskon_persen_1016 += 10
#     if status_member_1016 in ['y', 'ya']:
#         total_diskon_persen_1016 += 5
#     if promo_valid_1016 in ['y', 'ya']:
#         total_diskon_persen_1016 += 15
#     if jumlah_tiket_1016 >= 5:
#         total_diskon_persen_1016 += 5
#     ```
#     Jika `subtotal_1016 >= 200000` bernilai true maka akan menambah nilai 10 pada `total_diskon_persen_1016`. lanjut ke if berikutnya, jika `status_member_1016 in ['y', 'ya']` bernilai true maka akan menambah nilai 5 pada `total_diskon_persen_1016`. Jika `promo_valid_1016 in ['y', 'ya']` bernilai true maka akan menambah nilai 15 pada `total_diskon_persen_1016`. lanjut ke if berikutnya jika `jumlah_tiket_1016 >= 5` bernilai true maka akan menambah nilai 5 pada `total_diskon_persen_1016`.
#
# 14. ```
#     total_diskon_1016 = subtotal_1016 * (total_diskon_persen_1016/100)
#     total_bayar_1016 = subtotal_1016 - total_diskon_1016
#     ```
#     Menginisialisasi `total_diskon_1016` dan memberi nilai dengan hasil kali `subtotal_1016` dengan `(total_diskon_persen_1016/100)`. dan menginisialisasi `total_bayar_1016` dan memberi nilai dengan hasil kurang dari `subtotal_1016` dengan `total_diskon_1016`.
#
# 15. ```
#     print("\n---Rincian Pembayaran---")
#     print(f"Nama Pengunjung   : {nama_1016}")
#     print(f"Pilihan Paket     : {pilihan_paket_1016}")
#     print(f"Subtotal Belanja  : Rp {subtotal_1016:,.0f}")
#     print(f"Total Diskon      : {total_diskon_persen_1016}% (Rp {total_diskon_1016:,.0f}) ")
#     print(f"Total Bayar       : Rp {total_bayar_1016:,.0f}")
#     ```
#     Mencetak ---Rincian Pembayaran---,nama pengunjung, subtotal belanja, total diskon, dan total bayar. `f"..."` digunakan supaya bisa menyisipkan variabel didalam string. `:,.0f` digunakan untuk menampilkan angka desimal (float) dengan nol digit di belakang koma (dibulatkan ke bilangan bulat) dan menggunakan koma sebagai pemisah ribuan.
#
# 16. ```
#     if total_bayar_1016 > 300000:
#         print("Selamat! Anda berhak mendapatkan Souvenir Gratis.")
#         print("Terima kasih telah berkunjung.")
#     else:
#         print("Terima kasih telah berkunjung.")
#     print("Program Selesai")
#     ```
#     Melakukan percabangan jika `total_bayar_1016 > 300000` bernilai true maka akan mencetak "Selamat! Anda berhak mendapatkan Souvenir Gratis." dan "Terima kasih telah berkunjung". jika salah maka akan langsung menjalankan `else` dan mencetak "Terima kasih telah berkunjung". Pada akhir program akan mencetak "Program Selesai".

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN

# %% [markdown]
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan merupakan salah satu konsep penting dalam pemrograman Python. Dengan percabangan, program dapat memeriksa suatu kondisi dan menentukan tindakan yang sesuai. Struktur if, if-else, dan if-elif-else membantu program memilih instruksi berdasarkan hasil pemeriksaan kondisi, sedangkan multi-if memungkinkan beberapa kondisi diperiksa secara terpisah. Selain itu, match-case dapat digunakan untuk memilih tindakan berdasarkan nilai yang cocok dengan salah satu pola kasus.
#
# Melalui latihan yang dikerjakan, konsep percabangan tidak hanya dipelajari secara teori, tetapi juga diterapkan dalam program sederhana. Contohnya adalah penggunaan kondisi untuk memeriksa data pelanggan, seperti status member, jumlah belanja, jumlah barang, dan kode promo. Hasil pemeriksaan tersebut dapat digunakan untuk menentukan apakah pelanggan berhak memperoleh promo atau diskon tertentu. Program juga dapat mengolah data transaksi, seperti menghitung diskon, dan total pembayaran.
#
# Praktikum ini membantu penulis memahami bahwa pemilihan struktur percabangan perlu disesuaikan dengan kebutuhan program. Kondisi yang sederhana dapat ditangani dengan if, sedangkan beberapa pilihan yang saling berkaitan dapat ditulis menggunakan if-elif-else atau match-case. Dengan memahami cara kerja setiap struktur dan menyusun kondisi secara teliti, program dapat menjadi lebih teratur, mudah dibaca, dan menghasilkan keputusan yang sesuai dengan aturan yang telah ditentukan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. W3Schools. (n.d.). Python If...Else. W3Schools. https://www.w3schools.com/python/python_conditions.asp
#
# 2. GeeksforGeeks. (n.d.). Python match-case statement. GeeksforGeeks. https://www.geeksforgeeks.org/python/python-match-case-statement/
#
# 3. Petani Kode. (n.d.). Belajar percabangan if else pada Python. Petani Kode. https://www.petanikode.com/python-percabangan/
#
# 4. Python Software Foundation. (n.d.). More control flow tools. Python Documentation. https://docs.python.org/3/tutorial/controlflow.html
#
# 5. GeeksforGeeks. (n.d.). Python if-else. GeeksforGeeks. https://www.geeksforgeeks.org/python/python-if-else/
#
# 6. W3Schools. (n.d.). Python match case. W3Schools. https://www.w3schools.com/python/python_match.asp
